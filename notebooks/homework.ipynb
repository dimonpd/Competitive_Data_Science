# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from datashader.datashape import numeric
from seaborn import heatmap
from twisted.conch.insults.window import horizontalLine

# %%
import pandas as pd

df1 = pd.read_csv('https://stepik.org/media/attachments/lesson/681964/2.2.6_df1.csv', index_col=0)
df2 = pd.read_csv('https://stepik.org/media/attachments/lesson/681964/2.2.6_df2.csv', index_col=0)

# Учтите, что user_white_list и car_black_list в тестовой системе будут иметь другую длину и другие значения
user_white_list = ['g10995906g', 'H90312511Q', 'C27138482L', 'H22518078t', 'n17438464n', 'F10525768e', 's15596151o', 'i18954748S', 'E84048392U', 'E69893354s']
car_black_list = ['l-4285389z', 'n79502261g', 'N-1839822D']

# В ans содержится правильный ответ. Перед отправкой своего решения, сравнитесь с ним.
ans = pd.read_csv('https://stepik.org/media/attachments/lesson/681964/2_2_6_ans.csv', index_col=0)

# %%
new_df = pd.concat([df1, df2])

# %%
result =new_df.loc[(new_df.rating > 4) & ((new_df.stop_times ==2) | (new_df.stop_times == 3) | (new_df.stop_times == 5))]

# %%
mask1 = result['car_id'].isin(car_black_list)
mask2 = result['user_id'].isin(user_white_list)

# %%
result = result[~mask1 & mask2]

# %%
result = result[result.index % 2 == 0]

# %%
url ='https://raw.githubusercontent.com/a-milenkin/Competitive_Data_Science/main/data/driver_info.csv'

# %%
df = pd.read_csv(url)

# %%
df

# %%
mask1 = df.user_time_accident.between(4.5 ,9 , inclusive = 'right')
mask2 = df.age < 40

# %%
df = df[mask1 & mask2]
# Out:
# C:\Users\Dimon\AppData\Local\Temp\ipykernel_41416\3965308038.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   df = df[mask1 & mask2]

# %%
df.user_id.value_counts().sum()
# Out:
# 2478

# %%
import pandas as pd

df = pd.read_csv('https://stepik.org/media/attachments/lesson/681964/2_2_8.csv')

# В ans содержится правильный ответ. Перед отправкой своего решения, сравнитесь с ним.
ans = pd.read_csv('https://stepik.org/media/attachments/lesson/681964/2_2_8_ans.csv', index_col=0)

# %%
df['tripple_accident'] = df['user_time_accident'] * 3

# %%
df['rides_on_rating'] = df.user_rides / df.user_rating

# %%
df
# Out:
#        user_id  user_rating  age  user_rides  user_time_accident  \
# 0   f59331553m          7.7   29          99                 4.0
# 1   H50364497o          7.8   26         121                 0.0
# 2   A14869258v          7.3   34         557                 2.0
# 3   E10711310m          8.4   33         322                39.0
# 4   i54390205y          8.7   18          59                22.0
# ..         ...          ...  ...         ...                 ...
# 95  f43739690G          8.0   25         357                10.0
# 96  h51181620d          7.2   22        1421                13.0
# 97  l15352881X          8.0   25           2                14.0
# 98  k83620654u          8.5   27         156                 5.0
# 99  u47521230x          8.9   18         951                 8.0
#
#     tripple_accident  rides_on_rating
# 0               12.0        12.857143
# 1                0.0        15.512821
# 2                6.0        76.301370
# 3              117.0        38.333333
# 4               66.0         6.781609
# ..               ...              ...
# 95              30.0        44.625000
# 96              39.0       197.361111
# 97              42.0         0.250000
# 98              15.0        18.352941
# 99              24.0       106.853933
#
# [100 rows x 7 columns]

# %%
df = df[df.user_time_accident > 25]
# Out:
#        user_id  user_rating  age  user_rides  user_time_accident  \
# 3   E10711310m          8.4   33         322                39.0
# 37  b40165883m          8.5   18        2240                56.0
# 64  t25217963K          8.0   30         101                72.0
#
#     tripple_accident  rides_on_rating
# 3              117.0        38.333333
# 37             168.0       263.529412
# 64             216.0        12.625000

# %%
df = df[df.age > df.age.mean()]

# %%
df
# Out:
#        user_id  user_rating  age  user_rides  user_time_accident  \
# 3   E10711310m          8.4   33         322                39.0
# 64  t25217963K          8.0   30         101                72.0
#
#     tripple_accident  rides_on_rating
# 3              117.0        38.333333
# 64             216.0        12.625000

# %%
import pandas as pd

df = pd.read_csv('https://stepik.org/media/attachments/lesson/681964/2_2_10.csv')

# Учтите, что new_index, new_data, del_index_list, index в тестовой системе будут иметь другие значения
new_index = 50
new_data = ['new_car_id', 'new_worker_id', '2019-11-11 4:44','refuel_check', 3.5, 10]
del_index_list = [41, 18, 33, 7, 46]
index = 22


# В ans содержится правильный ответ. Перед отправкой своего решения, сравнитесь с ним.
ans = pd.read_csv('https://stepik.org/media/attachments/lesson/681964/2_2_10_ans.csv')

# %% [markdown]
# - Добавьте новую строку (с индексом new_index:(int / str) и значениями new_data:list).
# - Удалите строки с индексами из списка del_index_list: list.
# - Увеличьте значение destroy_degree на 1 в строке с индексом равным index. Переменная index содержит индекс строки ИЛИ число (индекс).
# - Удалите столбец fix_date, т.к. не стоит сейчас думать о времени.
# - Создайте новый столбец efficient, который равен destroy_degree деленный на work_duration.
# - Возведите столбец work_duration в квадрат.
# - Переименуйте столбец work_duration в work_duration_square.
# Удалите дубликаты по столбцу car_id.

# %%
df
# Out:
#         car_id      worker_id     work_type  destroy_degree  \
# 0   C-8860661H             BM     reparking             1.0
# 1   Z76775340d             IL        repair             8.4
# 2   r12485993Y             HN     reparking             1.0
# 3   Z-1382353b             VX        repair             5.7
# 4   p14707024B             JP  refuel_check             1.0
# 5   f-1883871J             LJ        repair             5.5
# 6   F-1518753o             ET        repair             5.0
# 8   F13192545Q             UY        repair             4.3
# 9   H12617664T             MV  refuel_check             1.0
# 10  V-2109665o             DH        repair             4.9
# 11  L45819441T             ND        repair             3.9
# 12  z48466812V             OX     reparking             1.0
# 13  e-2154304r             RT     reparking             1.0
# 14  Q-3414660J             SZ        repair             4.6
# 15  n-2248103n             JL     reparking             1.0
# 16  o90119190V             ZY     reparking             1.0
# 17  K-1010636S             KB        repair             5.2
# 19  h-1344515n             YJ     reparking             1.0
# 20  b-1448976u             QW        repair             6.9
# 21  E-1829228V             MD        repair             3.8
# 22  m-8965256V             XS  refuel_check             2.0
# 23  I-1538597J             RC        repair             5.8
# 24  n28625799A             WP        refuel             1.0
# 25  b-4266665E             MZ     reparking             1.0
# 26  v-1209318r             QN     reparking             1.0
# 27  h12427301o             WN        refuel             1.0
# 28  z-7198780T             RN        repair            10.0
# 29  b-1441595E             SG        repair             4.5
# 30  n31468349R             VW     reparking             1.0
# 31  Z95207161f             UJ        repair            10.0
# 32  n31468349R             IP     reparking             8.0
# 34  a10698807I             CS        repair             7.0
# 35  p81056764h             VY     reparking             1.0
# 36  K-1436228o             QH        repair             5.0
# 37  P62164543W             HC        repair             6.8
# 38  c-1411220k             IJ        refuel             1.0
# 39  B13169162p             CY     reparking             9.0
# 40  j51305093b             HP     reparking             1.0
# 42  v34523863p             FN     reparking             1.0
# 43  H97221372X             OW  refuel_check             1.0
# 44  l17843143j             XN        repair             5.5
# 45  j-1549044A             ZF        refuel             5.0
# 47  B18597537S             NR     reparking             1.0
# 48  H29930196K             NF        repair             5.0
# 49  p-2255017N             MN        repair             7.7
# 50  new_car_id  new_worker_id  refuel_check             3.5
#
#     work_duration_square  efficient
# 0                    784   0.035714
# 1                   2304   0.175000
# 2                    441   0.047619
# 3                    169   0.438462
# 4                    441   0.047619
# 5                    625   0.220000
# 6                    289   0.294118
# 8                    100   0.430000
# 9                    676   0.038462
# 10                   196   0.350000
# 11                     9   1.300000
# 12                   441   0.047619
# 13                   400   0.050000
# 14                   100   0.460000
# 15                   841   0.034483
# 16                   729   0.037037
# 17                   289   0.305882
# 19                   676   0.038462
# 20                  1521   0.176923
# 21                    25   0.760000
# 22                   400   0.100000
# 23                   484   0.263636
# 24                   676   0.038462
# 25                   289   0.058824
# 26                   484   0.045455
# 27                   784   0.035714
# 28                  2304   0.208333
# 29                     9   1.500000
# 30                   576   0.041667
# 31                  2304   0.208333
# 32                  1681   0.195122
# 34                   729   0.259259
# 35                   841   0.034483
# 36                   196   0.357143
# 37                  1156   0.200000
# 38                   729   0.037037
# 39                  2809   0.169811
# 40                   784   0.035714
# 42                   961   0.032258
# 43                   289   0.058824
# 44                   361   0.289474
# 45                  2209   0.106383
# 47                   676   0.038462
# 48                   225   0.333333
# 49                  1764   0.183333
# 50                   100   0.350000

# %%
df.loc[new_index] = new_data

# %%
df.drop(del_index_list , axis = 0, inplace = True)

# %%
df.loc[index, 'destroy_degree'] = df.loc[index, 'destroy_degree'] + 1

# %%
df.drop('fix_date', axis = 1, inplace = True)

# %%
df['efficient'] = df['destroy_degree'] / df['work_duration']

# %%
df.work_duration = df['work_duration'] ** 2

# %%
df.rename(columns = {'work_duration':'work_duration_square'}, inplace = True)

# %%
df = df.drop_duplicates('car_id', keep = 'first')

# %%
import pandas as pd

df = pd.read_csv('https://stepik.org/media/attachments/lesson/681964/2.2.11.csv')

# Учтите, что sort_by_list, cols2drop, columns_order_list в тестовой системе будут иметь другие значения.
sort_by_list = ['car_rating', 'riders']
cols2drop = ['random_name_1', 'target_reg', 'target_class', 'random_name_2']
columns_order_list = ['model', 'car_type', 'car_id', 'car_rating', 'year_to_start', 'year_to_work', 'riders', 'fuel_type']
critical_car_rating = 2

# В ans содержится правильный ответ. Перед отправкой своего решения, сравнитесь с ним.
ans = pd.read_csv('https://stepik.org/media/attachments/lesson/681964/2_2_11_ans.csv', index_col=0)

# %% [markdown]
# Задача:
#
# - Отсортируйте строки сначала по убыванию 1-го столбца из списка sort_by_list, затем по возрастанию 2-го столбца из списка.
# - Удалите столбцы из списка cols2drop с учетом того, что некоторых столбцов может не быть в df.
# - Сделайте порядок столбцов в df в соответствии с переменной columns_order_list: List[str].
# - Удалите строки, в которых car_rating < critical_car_rating.
# - Удалите строки, где число поездок riders больше 10_000, или тип машины car_type относится либо к standart, либо к economy.

# %%
df
# Out:
#            model  car_type      car_id  car_rating  year_to_start  \
# 4    Mini Cooper  business  i-4390733F        4.96           2012
# 295  Mini Cooper  business  b34607341j        4.04           2011
#
#      year_to_work  riders fuel_type
# 4            2018    1007    petrol
# 295          2018    2740    petrol

# %%
df = df.sort_values(by = [sort_by_list[0]], ascending = [False])

# %%
df = df.sort_values(by = [sort_by_list[1]], ascending = [True])

# %%
df = df.drop(cols2drop, axis = 1, errors='ignore')

# %%
df = df[columns_order_list]

# %%
mask1 = df['car_rating'] < critical_car_rating
mask2 = df['riders'] > 10_000 | df['car_type'].isin(['standart', 'economy'])

# %%
df = df[mask1]

# %%
df = df[mask2]
# Out:
# C:\Users\Dimon\AppData\Local\Temp\ipykernel_90252\3134942383.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   df = df[mask2]

# %%
df = df.sort_values(by=sort_by_list, ascending=[False, True])
df = df.drop(cols2drop, axis=1, errors='ignore')
df = df[columns_order_list]
df = df[df['car_rating'] >= critical_car_rating]
df = df[(df['riders'] <= 10_000) & (~df['car_type'].isin(['standart', 'economy']))]

# %%
df
# Out:
#            model  car_type      car_id  car_rating  year_to_start  \
# 4    Mini Cooper  business  i-4390733F        4.96           2012
# 295  Mini Cooper  business  b34607341j        4.04           2011
#
#      year_to_work  riders fuel_type
# 4            2018    1007    petrol
# 295          2018    2740    petrol

# %%
import pandas as pd

df = pd.read_csv('https://stepik.org/media/attachments/lesson/681964/2_2_12.csv')

# В ans содержится правильный ответ. Перед отправкой своего решения, сравнитесь с ним.
ans = pd.read_csv('https://stepik.org/media/attachments/lesson/681964/2_2_12_ans.csv')

# %% [markdown]
# Выполните по пунктам:
#
# - Запишите в переменную mean_rating среднее по столбцу car_rating .
# - Увеличьте на один все значения в столбцах car_rating и year_to_work.
# - Отфильтруйте любым из удобных способов машины с рейтингом выше среднего от столбца car_rating (используйте переменную mean_rating).
# - Преобразуйте столбец year_to_work следующим образом: если значение меньше 2017, то прибавьте 2, иначе разделите значение нацело на 5.
# - Переименуйте столбец year_to_start в new_year_to_start и удалите столбец fuel_type.
# - Ко всем значениям из столбца car_type добавьте приставку super_ (standart -> super_standart).
# - Решение запишите в переменную result.

# %%
df
# Out:
#     Unnamed: 0      car_id           model  car_type fuel_type  car_rating  \
# 0            0  o-1588203t      VW Polo VI   economy    petrol        5.04
# 1            1  B-1760099A  Renault Kaptur  standart    petrol        5.36
# 2            2  u-2045579o  Renault Kaptur  standart    petrol        6.94
# 3            3  V-4730687q       VW Tiguan   economy    petrol        5.10
# 4            4  K23027223e    Smart ForTwo   economy    petrol        4.82
# ..         ...         ...             ...       ...       ...         ...
# 95          95  i22101695X        Fiat 500  business    petrol        6.16
# 96          96  a22370652k         Kia Rio   economy    petrol        5.56
# 97          97  H-1952766q   Tesla Model 3   premium   electro        5.92
# 98          98  r13675823Y      VW Polo VI   economy    petrol        5.36
# 99          99  I-1117298r       VW Tiguan   economy    petrol        5.54
#
#     year_to_start  riders  year_to_work  target_reg     target_class
# 0            2014   61872          2015   46.175419     engine_check
# 1            2015   95768          2020   30.585652  engine_overheat
# 2            2012   21114          2020   68.091881  engine_ignition
# 3            2016   95799          2018   39.808397        break_bug
# 4            2017  127971          2022   37.024779      electro_bug
# ..            ...     ...           ...         ...              ...
# 95           2015   80937          2022   54.714139     engine_check
# 96           2013   46108          2021   31.320599        break_bug
# 97           2014   58631          2019   50.306346       gear_stick
# 98           2015   84108          2018   34.150655      engine_fuel
# 99           2015   82807          2019  111.275852      another_bug
#
# [100 rows x 11 columns]

# %%
mean_rating = df['car_rating'].mean()

# %%
df['car_rating'] = df['car_rating'] + 1
df['year_to_work'] = df['year_to_work'] + 1

# %%
mask = df['car_rating'] > mean_rating

# %%
df = df[mask]

# %%
df['year_to_work'] = df['year_to_work'].apply(lambda x: x + 1 if x < 2017 else x / 5)

# %%
df['fuel_type'] = None

# %%
df['car_type'] = df['car_type'].apply(lambda x: 'super_' + x)

# %%
result = df

# %%
# Увеличьте на один все значения в столбцах car_rating и year_to_work
df['car_rating'] = df['car_rating'] + 1
df['year_to_work'] = df['year_to_work'] + 1

# Отфильтруйте любым из удобных способов машины с рейтингом выше среднего от столбца car_rating (используйте переменную mean_rating)
df = df[df['car_rating'] > mean_rating]

# Преобразуйте столбец year_to_work следующим образом: если значение меньше 2017, то прибавьте 2, иначе разделите значение нацело на 5
df['year_to_work'] = df['year_to_work'].apply(lambda x: x + 2 if x < 2017 else x // 5)

# Переименуйте столбец year_to_start в new_year_to_start и удалите столбец fuel_type
df = df.rename(columns={'year_to_start': 'new_year_to_start'})
df = df.drop('fuel_type', axis=1)

# Ко всем значениям из столбца car_type добавьте приставку super_ (standart -> super_standart)
df['car_type'] = df['car_type'].apply(lambda x: 'super_' + x)

# Решение запишите в переменную result
result = df

# %%
df
# Out:
#     Unnamed: 0      car_id            model        car_type  car_rating  \
# 2            2  u-2045579o   Renault Kaptur  super_standart        6.94
# 9            9  i-2071885N     Smart ForTwo   super_economy        7.32
# 37          37  K-9089430v   Nissan Qashqai  super_standart        6.66
# 44          44  J-6052671x  Renault Sandero  super_standart        7.84
# 46          46  M-1459552x  Renault Sandero  super_standart        6.62
# 49          49  p-8776685b     Smart ForTwo   super_economy        7.74
# 63          63  R-2878244Q   Renault Kaptur  super_standart        7.04
# 71          71  P-1313124Y   Nissan Qashqai  super_standart        7.00
# 76          76  c-2121060b      Skoda Rapid   super_economy        6.48
# 81          81  R-2027359R          Kia Rio   super_economy        7.80
# 90          90  q-1778461b     Smart ForTwo   super_economy        7.42
#
#     new_year_to_start  riders  year_to_work  target_reg     target_class
# 2                2012   21114           404   68.091881  engine_ignition
# 9                2015   85858           403   63.002043  engine_ignition
# 37               2015   83696           404   53.975565  engine_ignition
# 44               2013   44075           404   37.743954  engine_overheat
# 46               2013   38104           404   37.259225        break_bug
# 49               2016   98683           404   48.088650     engine_check
# 63               2013   51617           403   32.933191        break_bug
# 71               2013   41511           404   31.333229  engine_overheat
# 76               2017  110542          2017   41.559854      electro_bug
# 81               2011    2206           404   24.622714      wheel_shake
# 90               2017  108795           403   44.950002  engine_overheat

# %%
ans
# Out:
#     Unnamed: 0      car_id           model        car_type  car_rating  \
# 0            0  o-1588203t      VW Polo VI   super_economy        5.04
# 1            1  B-1760099A  Renault Kaptur  super_standart        5.36
# 2            2  u-2045579o  Renault Kaptur  super_standart        6.94
# 3            3  V-4730687q       VW Tiguan   super_economy        5.10
# 4            4  K23027223e    Smart ForTwo   super_economy        4.82
# ..         ...         ...             ...             ...         ...
# 85          95  i22101695X        Fiat 500  super_business        6.16
# 86          96  a22370652k         Kia Rio   super_economy        5.56
# 87          97  H-1952766q   Tesla Model 3   super_premium        5.92
# 88          98  r13675823Y      VW Polo VI   super_economy        5.36
# 89          99  I-1117298r       VW Tiguan   super_economy        5.54
#
#     new_year_to_start  riders  year_to_work  target_reg     target_class
# 0                2014   61872          2018   46.175419     engine_check
# 1                2015   95768           404   30.585652  engine_overheat
# 2                2012   21114           404   68.091881  engine_ignition
# 3                2016   95799           403   39.808397        break_bug
# 4                2017  127971           404   37.024779      electro_bug
# ..                ...     ...           ...         ...              ...
# 85               2015   80937           404   54.714139     engine_check
# 86               2013   46108           404   31.320599        break_bug
# 87               2014   58631           404   50.306346       gear_stick
# 88               2015   84108           403   34.150655      engine_fuel
# 89               2015   82807           404  111.275852      another_bug
#
# [90 rows x 10 columns]

# %%
pd.options.mode.copy_on_write = True

# %%
import pandas as pd

df = pd.read_csv('https://stepik.org/media/attachments/lesson/681964/2_2_13.csv')

# Учтите, что cols2drop в тестовой системе будет иметь другие значения.
cols2drop = ['ride_cost', 'stop_times', 'user_ride_quality']

# В ans содержится правильный ответ. Перед отправкой своего решения, сравнитесь с ним.
ans = pd.read_csv('https://stepik.org/media/attachments/lesson/681964/2_2_13_ans.csv', index_col=0)

# %% [markdown]
# Задача:
#
# - Добавьте столбец flag, который равен 'good_line', если rating > 5 and speed_max < 100. 'bad_line', если  rating > 5 and speed_max > 100. 'undefined' в остальных случаях.
# - Добавьте столбец speed_check, который принимает значения 'avg_more', если distance/ride_duration > speed_avg, иначе 'avg_less'.
# - Удалите столбцы из списка cols2drop.
# - Удалите строки, в которых car_id имеет пустые значения (только NA удаляем).
# - Результат запишите в переменную result.

# %%
df
# Out:
#        user_id      car_id ride_id   ride_date  rating  ride_duration  \
# 0   Q57343968C  i-6289789v     F1u  2020-03-02    1.79             35
# 1   N39662076X  F17991047v     J1A  2020-03-16    4.36             16
# 2   R39462885w  l36861534V     m1v  2020-01-20    2.20              5
# 3   q32765597m  R16189354h     v1q  2020-02-24    2.82             10
# 4   n30214850g  N-1839822D     p1h  2020-01-31    3.54             17
# 5   d91252688Z  F93868144g     B1l  2020-03-11    4.19             45
# 6   Y20252297D  S-1468454C     p1H  2020-01-28    2.99             42
# 7   P10687833d  s-1070927u     A1x  2020-02-21    4.37            113
# 8   u66859508D  q22813846g     r1G  2020-03-04    1.22             83
# 9   B22048029D  W10497593m     a1L  2020-03-30    7.51            154
# 10  E10011084Z  f-8313064a     r1F  2020-02-23    6.27             45
# 11  d72380629z  H44042475h     E1R  2020-03-24    3.83             51
# 12  W24493253v  l93168360C     u1f  2020-03-11    3.33             31
# 13  G14162631Z  D44517833b     M1L  2020-02-03    0.37             37
# 14  w20780850o  k49230827x     Q1c  2020-01-03    5.56              5
# 15  T17969595Q  v60921451s     e1H  2020-02-20    4.86             50
# 16  x79241754t  G-1150322W     q1a  2020-03-29    6.48             37
# 17  X20411644t  u21483945j     i1I  2020-03-07    1.70             62
# 18  m85537990B  O19079001s     D1E  2020-03-11    5.85              3
# 19  Q59860368x  Y-1015822T     X1L  2020-01-23    4.99            435
# 20  D83327981K  G-1577332Q     T1t  2020-02-01   10.00             20
# 21  c11472483K         NaN     g1Z  2020-02-23    4.88              9
# 22  u16841707D  H12470081t     F1W  2020-01-29    3.74             21
# 23  I16576803I  V-9683916q     D1v  2020-03-29    0.73             39
# 24  J35647204F  s18801959g     x1t  2020-03-20    3.89             50
# 25  k20388547K         NaN     W1q  2020-01-16    2.68             25
# 26  m17865791g  a10378761Y     x1Z  2020-01-03    5.31             42
# 27  J16666485Z  R14058273F     P1g  2020-03-10    5.08           8598
# 28  D16324221o         NaN     Y1k  2020-03-06    5.49             98
# 29  N10397594A  x58256990o     C1e  2020-01-29    5.26            105
# 30  e47183814o  C-5107111N     y1C  2020-03-13    2.13             53
# 31  U18440405R  A20603057e     k1v  2020-03-26    7.15          19499
# 32  V17751237h  n10206436k     z1K  2020-02-16    5.11             13
# 33  u17269130P  r-5540835r     G1P  2020-03-17    4.45             59
# 34  w20261700K         NaN     k1i  2020-01-07    7.76             15
# 35  x11584611E  b-7314701z     W1i  2020-02-26    0.76           9535
# 36  g19017632H  i12167734p     T1o  2020-03-08    2.33             47
# 37  T82008116X  b-1681467p     h1Q  2020-01-09    9.01             42
# 38  u95988277B  c75592211G     q1L  2020-03-23    3.91             80
# 39  f60290890A         NaN     g1F  2020-02-17    6.81             12
# 40  X12509304t  i-2886682y     X1r  2020-01-07    0.61           4125
# 41  F22595456y  S42953963r     E1b  2020-03-30    3.76             51
# 42  w30463740Q  S17802902i     m1n  2020-01-05    5.12             15
# 43  b60807772D  L-1748371J     H1B  2020-01-09    4.48          28890
# 44  C22812187t  z-1435869q     S1a  2020-01-06    1.73             51
# 45  B65872491M         NaN     U1E  2020-01-30    3.66             22
# 46  V40970698X  x-1530392k     n1B  2020-02-03    0.10            195
# 47  u10215024g         NaN     X1A  2020-02-22    8.18             20
# 48  s34597021Z  I21674635Q     u1X  2020-01-07    6.09              3
# 49  M11969095I  K-5008643Z     g1p  2020-03-27    6.30              6
#
#     ride_cost  speed_avg   speed_max  stop_times      distance  refueling  \
# 0         275         87  125.463335           0  2.930798e+03          0
# 1         202         36   63.275887           0  4.729460e+02          0
# 2          60         47   73.000000           0  2.836265e+02          0
# 3         154         31   76.838507           1  1.007437e+02          0
# 4         163         26   53.000000           1  2.684519e+02          0
# 5         535         41   54.815139           1  1.961271e+03          0
# 6         330         67   75.324044           0  2.902271e+03          0
# 7         900         45  101.000000          12  1.389693e+03          0
# 8         825         33   78.000000           1  2.575376e+03          0
# 9        1380         33   46.000000           0  9.417631e+02          0
# 10        622         52   62.000000           1  1.275346e+03          0
# 11        556         54   95.000000           1  2.698453e+03          0
# 12        493         48   66.000000           0  1.052461e+03          0
# 13        363         41   71.523469           0  1.506986e+03          0
# 14         76         63   71.000000           0  2.504995e+02          0
# 15        643         39   70.000000           1  1.661154e+03          0
# 16        366         47   88.544287           1  1.479930e+03          0
# 17        986         73  152.398053           1  4.078603e+03          0
# 18         27         54   64.238713           0  1.694870e+02          0
# 19       4779         36  124.000000           1  1.086387e+03          0
# 20        175         45  121.922976           1  9.388084e+02          0
# 21         68         51   91.000000           1  4.797543e+01          0
# 22        287         37   63.000000           3  3.134473e+02          0
# 23        501         88  198.388893           0  3.530341e+03          0
# 24       2496         47   71.000000           0  2.317616e+03          0
# 25        295         52   69.000000           1  1.273967e+03          0
# 26        415         39  117.000000           7  1.361887e+03          0
# 27      77377         52   69.000000           1  4.543380e+05          0
# 28        974         54  169.194779           0  1.118991e+03          0
# 29       1361         47   55.000000           2  1.495010e+03          0
# 30        737         51   57.000000           1  1.922402e+03          0
# 31     272981         68  167.167452           3  1.340785e+06          0
# 32        139         45   73.000000           0  2.906956e+02          0
# 33        818         51   89.202101           0  2.560686e+03          0
# 34        234         52   61.000000           0  3.815775e+02          0
# 35     123950         89  172.699298           0  8.568368e+05          0
# 36        372         54  112.000000           9  1.462185e+03          0
# 37        667         31   49.000000           1  1.144362e+03          0
# 38        813         50  145.000000           9  2.567906e+03          0
# 39        354         41   67.000000           1  1.781579e+02          0
# 40      49495         51   71.000000          15  2.142162e+03          0
# 41        809         41   70.000000           1  2.029641e+03          0
# 42        131         54   77.388694           0  8.755882e+02          0
# 43     231113         61   81.521292           0  1.800509e+06          0
# 44        504         67  115.419262           0  3.355922e+03          0
# 45        236         52   80.348088           0  1.153537e+03          0
# 46       2337         42  138.000000           0  1.847684e+03          0
# 47        275         48   63.000000           1  6.401971e+02          0
# 48         32         61   92.600171           0  2.318474e+02          0
# 49         53         46   74.000000           0  1.465846e+02          0
#
#     user_ride_quality  deviation_normal
# 0          -11.132653            -8.683
# 1          -28.508294           -37.196
# 2           -0.203089             3.378
# 3            0.219071            14.758
# 4           15.763025            21.179
# 5            4.488745           -22.288
# 6           11.045684            -0.000
# 7           12.707721           -30.737
# 8          -12.372173            -3.397
# 9           -6.084587           -23.284
# 10          -2.713337             0.216
# 11          -6.137158            -3.397
# 12          -8.815905            -2.028
# 13           4.066301            50.284
# 14          -5.616321             4.976
# 15           1.476753            -1.700
# 16          -0.721480             0.003
# 17         -10.769368            26.047
# 18          14.767933           -13.276
# 19          -5.748896            -2.676
# 20          -7.969811            -0.000
# 21                NaN            -0.600
# 22          10.323028             0.001
# 23          12.456049            34.544
# 24          13.802005            19.251
# 25           8.147698           -40.529
# 26          -0.102120             1.394
# 27           0.467344             3.304
# 28           7.315399           -21.576
# 29           5.567516           -12.699
# 30           7.641451             1.592
# 31           5.006012            -5.900
# 32          12.456554            34.149
# 33          -0.920452            20.120
# 34          -4.063703            -0.000
# 35          -9.857886            -1.286
# 36         -40.424901           -37.663
# 37          -4.432075             0.001
# 38          20.763007             0.002
# 39         -10.144770           -17.371
# 40          -4.638991             0.000
# 41         -23.051856            -0.854
# 42          -4.998286            16.484
# 43          -0.005131             2.602
# 44           1.448805           -18.669
# 45           7.518149            19.120
# 46         -11.476413            34.588
# 47          -8.796505             0.177
# 48           5.573260             1.810
# 49          -5.599562             0.073

# %%
df['flag'] = df.apply(lambda x: 'good_line' if x['rating'] > 5 and x['speed_max'] < 100 else 'bad_line' if x['rating'] > 5 and x['speed_max'] > 100 else 'undefined', axis=1)

# %%
df['speed_check'] = df.apply(lambda x: 'avg_more' if x['distance'] / x['ride_duration'] > x['speed_avg'] else 'avg_less', axis=1)

# %%
df = df.drop(cols2drop, axis=1)

# %%
df = df.dropna(subset=['car_id'])

# %%
result = df

# %%
ans

# %%
from pandarallel import pandarallel
pandarallel.initialize(progress_bar=True)
# Out:
# INFO: Pandarallel will run on 16 workers.
# INFO: Pandarallel will use standard multiprocessing data transfer (pipe) to transfer data between the main process and workers.
#
# WARNING: You are on Windows. If you detect any issue with pandarallel, be sure you checked out the Troubleshooting page:
# https://nalepae.github.io/pandarallel/troubleshooting/

# %%
import pandas as pd

df = pd.read_csv('https://stepik.org/media/attachments/lesson/681964/2_2_14.csv')

# В ans содержится правильный ответ. Перед отправкой своего решения, сравнитесь с ним.
ans = pd.read_csv('https://stepik.org/media/attachments/lesson/681964/2_2_14_ans.csv', index_col=0)

# %%
df
# Out:
#     Unnamed: 0   age  user_rating  user_rides  user_time_accident     user_id  \
# 0            0  36.0          8.1       907.0                 NaN  t47293129J
# 1            1  32.0          8.3       343.0                15.0  C20968936W
# 2            2   NaN          8.4      1485.0                16.0  O67053864f
# 3            3  32.0          7.8       852.0                 5.0  B19144385S
# 4            4  34.0          8.1       344.0                 NaN  e19659653o
# 5            5  35.0          7.6      1124.0                 3.0  i13337141O
# 6            6  34.0          6.6       677.0                 7.0  R14765574G
# 7            7  34.0          NaN       911.0                 NaN  V22523922K
# 8            8  26.0          8.2       629.0                12.0  f21927212F
# 9            9  22.0          8.9       208.0                 7.0  a21963875W
# 10          10  22.0          7.9       157.0                 3.0  A16223784v
# 11          11   NaN          9.2       392.0                19.0  n11238565X
# 12          12  53.0          8.7      1412.0                 NaN  z10721091f
# 13          13  20.0          8.4      2100.0                 NaN  W15747881k
# 14          14  43.0          8.1         NaN                 8.0  H10387531M
# 15          15   NaN          8.3       800.0                13.0  v46859571V
# 16          16  42.0          8.2       864.0                14.0  F99881585n
# 17          17   NaN          NaN      1122.0                 NaN  X20181795w
# 18          18  23.0          NaN       417.0                 8.0  h92384864O
# 19          19   NaN          NaN       996.0                14.0  G17860529I
# 20          20  22.0          8.9       912.0                 NaN  v13187334X
# 21          21  31.0          8.2      1234.0                 8.0  m98514187S
# 22          22  49.0          8.8       621.0                24.0  a17134345I
# 23          23   NaN          NaN       134.0                 NaN  q21621167D
# 24          24  18.0          8.6       968.0                 NaN  v15338707J
# 25          25  36.0          7.7       980.0                 NaN  u60501674q
# 26          26  29.0          NaN       540.0                 6.0  R13406529h
# 27          27   NaN          8.7       100.0                 NaN  O16778416p
# 28          28  36.0          8.8      1814.0                10.0  I30026246b
# 29          29   NaN          NaN       805.0                12.0  w71669790h
# 30          30   NaN          7.1       631.0                 NaN  L68827794P
# 31          31  38.0          9.1       547.0                15.0  P12891086o
# 32          32  42.0          7.3       306.0                10.0  i10027937K
# 33          33  47.0          7.8       172.0                 NaN  S33408708R
# 34          34   NaN          7.9       861.0                 9.0  b14453950T
# 35          35  39.0          9.0      1073.0                 NaN  d73864630g
# 36          36  18.0          8.8       805.0                15.0  p10005294E
# 37          37  18.0          8.6      2902.0                10.0  c72094812O
# 38          38  49.0          8.3         NaN                 NaN  R13755138S
# 39          39   NaN          9.1       464.0                 NaN  L25054795y
# 40          40  35.0          7.5      1206.0                 1.0  S25739559x
# 41          41  30.0          9.1       823.0                14.0  U21676248m
# 42          42  19.0          8.0      1753.0                10.0  H13138669d
# 43          43   NaN          NaN       996.0                 NaN  n65464289O
# 44          44  24.0          NaN       173.0                 NaN  H98300938t
# 45          45  47.0          8.0       996.0                 NaN  p15463825w
# 46          46   NaN          NaN       992.0                 NaN  p17056948y
# 47          47  24.0          7.9      1130.0                 NaN  X17153340S
# 48          48   NaN          7.8       600.0                 7.0  Q19565895U
# 49          49  30.0          8.2       103.0                 NaN  i28723616D
#
#     sex first_ride_date  nans_num
# 0     0       2020-10-9         1
# 1     0             NaN         1
# 2     0        2021-6-6         1
# 3     1       2020-9-23         0
# 4     1       2020-5-12         1
# 5     0       2019-1-22         0
# 6     0             NaN         1
# 7     1             NaN         3
# 8     1       2019-5-30         0
# 9     1        2020-4-7         0
# 10    1       2020-3-22         0
# 11    1       2020-5-23         1
# 12    0       2021-5-16         1
# 13    1      2021-11-15         1
# 14    0       2021-2-25         1
# 15    0       2019-4-17         1
# 16    0       2019-3-29         0
# 17    0        2021-3-2         3
# 18    1       2020-5-29         1
# 19    1       2020-11-3         2
# 20    1      2020-10-10         1
# 21    0       2021-3-28         0
# 22    0        2019-6-5         0
# 23    1      2019-12-20         3
# 24    1      2020-10-23         1
# 25    0      2020-10-26         1
# 26    1        2020-7-4         1
# 27    0      2019-10-19         2
# 28    0             NaN         1
# 29    1       2020-9-12         2
# 30    0        2019-6-3         2
# 31    0       2019-6-22         0
# 32    0       2020-4-30         0
# 33    0       2019-9-29         1
# 34    0             NaN         2
# 35    0        2019-2-7         1
# 36    1       2020-9-12         0
# 37    1       2017-4-17         0
# 38    0       2019-4-17         2
# 39    1       2020-6-13         2
# 40    0      2020-12-25         0
# 41    1             NaN         1
# 42    1       2018-5-13         0
# 43    0       2019-2-25         3
# 44    1             NaN         3
# 45    0       2019-2-25         1
# 46    1       2020-11-2         3
# 47    1        2021-3-4         1
# 48    0       2020-7-18         1
# 49    1      2019-12-13         1

# %% [markdown]
# - Посчитайте количество пропусков в каждой строке и запишите это в новый столбец nans_num.
# - Удалите строки, где количество пропусков больше 2.
# - Удалите строки, где age имеет пропущенные значения.
# - Заполните пропущенные значения в столбце user_time_accident медианным значением.
# - Оставьте только столбцы age, user_rides, user_time_accident.
# - Решение запишите в переменную result.

# %%
df['nans_num'] = df.isna().sum(axis=1)

# %%
df = df.dropna(thresh=3)

# %%
df = df.dropna(subset=['age'])

# %%
df['user_time_accident'] = df['user_time_accident'].fillna(df['user_time_accident'].median())

# %%
df = df[['age', 'user_rides', 'user_time_accident']]

# %%
result = df

# %%
ans

# %%
plt.figure(figsize=(20, 5))
g = sns.lineplot(data = rides_info,
                 x = 'ride_date',
                 y = 'deviation_normal',
                 hue='target_class',
                 legend=True)

g.set_xticklabels(g.get_xticklabels(), rotation=45, horizontalalignment='right')
g.xaxis.set_major_locator(ticker.MultipleLocator(2));
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 plt.figure(figsize=(20, 5))
#       2 g = sns.lineplot(data = rides_info,
#       3                  x = 'ride_date',
#       4                  y = 'deviation_normal',
#       5                  hue='target_class',
#       6                  legend=True)
#       8 g.set_xticklabels(g.get_xticklabels(), rotation=45, horizontalalignment='right')
#
# NameError: name 'plt' is not defined

# %%
path = 'https://raw.githubusercontent.com/a-milenkin/Competitive_Data_Science/main/data/car_train.csv'
df = pd.read_csv(path)
df.head()
# Out:
#        car_id              model  car_type fuel_type  car_rating  \
# 0  y13744087j     Kia Rio X-line   economy    petrol        3.78
# 1  O41613818T         VW Polo VI   economy    petrol        3.90
# 2  d-2109686j    Renault Sandero  standart    petrol        6.30
# 3  u29695600e  Mercedes-Benz GLC  business    petrol        4.04
# 4  N-8915870N    Renault Sandero  standart    petrol        4.70
#
#    year_to_start  riders  year_to_work  target_reg target_class
# 0           2015   76163          2021      108.53  another_bug
# 1           2015   78218          2021       35.20  electro_bug
# 2           2012   23340          2017       38.62   gear_stick
# 3           2011    1263          2020       30.34  engine_fuel
# 4           2012   26428          2017       30.45  engine_fuel

# %%
plt.rcParams["figure.figsize"] = (12, 12)

# %%
heatmap = sns.heatmap(
    df.corr(numeric_only=True).round(2),
    annot=True,
    square=True,
    cmap='Blues',
    cbar_kws={'fraction': 0.01},
    linewidths=2,
)

heatmap.set_yticklabels(heatmap.get_yticklabels(), rotation = 45, horizontalLine='right')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[22], line 10
#       1 heatmap = sns.heatmap(
#       2     df.corr(numeric_only=True).round(2),
#       3     annot=True,
#    (...)
#       7     linewidths=2,
#       8 )
# ---> 10 heatmap.set_yticklabels(heatmap.get_yticklabels(), rotation = 45, horizontalLine='right')
#
# File c:\Users\Dimon\anaconda3\Lib\site-packages\matplotlib\axes\_base.py:73, in _axis_method_wrapper.__set_name__.<locals>.wrapper(self, *args, **kwargs)
#      72 def wrapper(self, *args, **kwargs):
# ---> 73     return get_method(self)(*args, **kwargs)
#
# File c:\Users\Dimon\anaconda3\Lib\site-packages\matplotlib\_api\deprecation.py:297, in rename_parameter.<locals>.wrapper(*args, **kwargs)
#     292     warn_deprecated(
#     293         since, message=f"The {old!r} parameter of {func.__name__}() "
#     294         f"has been renamed {new!r} since Matplotlib {since}; support "
#     295         f"for the old name will be dropped %(removal)s.")
#     296     kwargs[new] = kwargs.pop(old)
# --> 297 return func(*args, **kwargs)
#
# File c:\Users\Dimon\anaconda3\Lib\site-packages\matplotlib\axis.py:2060, in Axis.set_ticklabels(self, labels, minor, fontdict, **kwargs)
#    2058 # deal with label1
#    2059 tick.label1.set_text(tick_label)
# -> 2060 tick.label1._internal_update(kwargs)
#    2061 # deal with label2
#    2062 tick.label2.set_text(tick_label)
#
# File c:\Users\Dimon\anaconda3\Lib\site-packages\matplotlib\artist.py:1219, in Artist._internal_update(self, kwargs)
#    1212 def _internal_update(self, kwargs):
#    1213     """
#    1214     Update artist properties without prenormalizing them, but generating
#    1215     errors as if calling `set`.
#    1216
#    1217     The lack of prenormalization is to maintain backcompatibility.
#    1218     """
# -> 1219     return self._update_props(
#    1220         kwargs, "{cls.__name__}.set() got an unexpected keyword argument "
#    1221         "{prop_name!r}")
#
# File c:\Users\Dimon\anaconda3\Lib\site-packages\matplotlib\artist.py:1193, in Artist._update_props(self, props, errfmt)
#    1191             func = getattr(self, f"set_{k}", None)
#    1192             if not callable(func):
# -> 1193                 raise AttributeError(
#    1194                     errfmt.format(cls=type(self), prop_name=k))
#    1195             ret.append(func(v))
#    1196 if ret:
#
# AttributeError: Text.set() got an unexpected keyword argument 'horizontalLine'

# %%
g = sns.relplot(
    data=df,
    x='model',
    y='target_class',
    hue='target_reg',
    kind='line',
    aspect=4,
)

g.set_xticklabels(rotation=45, horizontalalignment='right', step=2)

# %%
df.hist(figsize=(25, 6), layout=(-1, 6))
# Out:
# array([[<Axes: title={'center': 'car_rating'}>,
#         <Axes: title={'center': 'year_to_start'}>,
#         <Axes: title={'center': 'riders'}>,
#         <Axes: title={'center': 'year_to_work'}>,
#         <Axes: title={'center': 'target_reg'}>, <Axes: >]], dtype=object)

# %%
import pandas as pd
import seaborn as sns

# Assuming you have the 'column1' and 'column2' in your DataFrame
crosstab = pd.crosstab(df['model'], df['target_class'])

# Display the crosstab
print(crosstab)

# Create a heatmap of the crosstab
sns.heatmap(crosstab, annot=True, cmap='YlGnBu')

# Show the heatmap
plt.show()
# Out:
# target_class        another_bug  break_bug  electro_bug  engine_check  \
# model
# Audi A3                       2          3            3             2
# Audi A4                       3          4            1             3
# Audi Q3                       3          0            6             1
# BMW 320i                      2          1            1             5
# Fiat 500                      0          3            1             3
# Hyundai Solaris              25         13           13            17
# Kia Rio                      16         14           12            11
# Kia Rio X                    19         13           14            16
# Kia Rio X-line               18         12           17            13
# Kia Sportage                 22         21           13            18
# MINI CooperSE                 6          4            0             3
# Mercedes-Benz E200            1          3            3             6
# Mercedes-Benz GLC             3          2            5             0
# Mini Cooper                   1          1            2             4
# Nissan Qashqai               16         10           17            14
# Renault Kaptur               16         20           14            22
# Renault Sandero              22         19           12            12
# Skoda Rapid                  16         24           17            20
# Smart Coupe                  11         16           13            12
# Smart ForFour                21         18           13            16
# Smart ForTwo                  7         16           19            15
# Tesla Model 3                 2          1            2             2
# VW Polo                       9         20           15            23
# VW Polo VI                   21         13           18            18
# VW Tiguan                    16         18           14            14
# Volkswagen ID.4               1          1            4             0
#
# target_class        engine_fuel  engine_ignition  engine_overheat  gear_stick  \
# model
# Audi A3                       2                2                1           2
# Audi A4                       2                2                3           2
# Audi Q3                       4                1                4           2
# BMW 320i                      1                3                1           2
# Fiat 500                      0                1                5           5
# Hyundai Solaris              22               17               20          18
# Kia Rio                      11               12               11          13
# Kia Rio X                    11               20               15          15
# Kia Rio X-line               18               14               16          17
# Kia Sportage                 19               15               19          20
# MINI CooperSE                 0                2                4           2
# Mercedes-Benz E200            2                0                5           3
# Mercedes-Benz GLC             2                0                3           2
# Mini Cooper                   5                3                5           1
# Nissan Qashqai               19               30               23          17
# Renault Kaptur               22               11               24          25
# Renault Sandero              22               23               24          18
# Skoda Rapid                  13               16               10          17
# Smart Coupe                  12               17               11          15
# Smart ForFour                18               20               17          21
# Smart ForTwo                 14               14               16          18
# Tesla Model 3                 3                2                0           2
# VW Polo                      18               12               16          15
# VW Polo VI                    7               15               17          20
# VW Tiguan                    13               16               16          11
# Volkswagen ID.4               2                1                3           1
#
# target_class        wheel_shake
# model
# Audi A3                       0
# Audi A4                       0
# Audi Q3                       0
# BMW 320i                      0
# Fiat 500                      0
# Hyundai Solaris              16
# Kia Rio                      11
# Kia Rio X                    20
# Kia Rio X-line               15
# Kia Sportage                  0
# MINI CooperSE                 0
# Mercedes-Benz E200            0
# Mercedes-Benz GLC             0
# Mini Cooper                   0
# Nissan Qashqai                0
# Renault Kaptur                0
# Renault Sandero               0
# Skoda Rapid                  14
# Smart Coupe                  11
# Smart ForFour                14
# Smart ForTwo                 11
# Tesla Model 3                 0
# VW Polo                      13
# VW Polo VI                   23
# VW Tiguan                    17
# Volkswagen ID.4               0

# %%
df
# Out:
#           car_id              model  car_type fuel_type  car_rating  \
# 0     y13744087j     Kia Rio X-line   economy    petrol        3.78
# 1     O41613818T         VW Polo VI   economy    petrol        3.90
# 2     d-2109686j    Renault Sandero  standart    petrol        6.30
# 3     u29695600e  Mercedes-Benz GLC  business    petrol        4.04
# 4     N-8915870N    Renault Sandero  standart    petrol        4.70
# ...          ...                ...       ...       ...         ...
# 2332  j21246192N      Smart ForFour   economy    petrol        4.38
# 2333  h-1554287F            Audi A4   premium    petrol        4.30
# 2334  A15262612g            Kia Rio   economy    petrol        3.88
# 2335  W-2514493U    Renault Sandero  standart    petrol        4.50
# 2336  z-1337463D            VW Polo   economy    petrol        3.94
#
#       year_to_start  riders  year_to_work  target_reg  target_class
# 0              2015   76163          2021      108.53   another_bug
# 1              2015   78218          2021       35.20   electro_bug
# 2              2012   23340          2017       38.62    gear_stick
# 3              2011    1263          2020       30.34   engine_fuel
# 4              2012   26428          2017       30.45   engine_fuel
# ...             ...     ...           ...         ...           ...
# 2332           2017  121239          2018       25.48   wheel_shake
# 2333           2016  107793          2020       69.26  engine_check
# 2334           2015   80234          2019       46.03    gear_stick
# 2335           2014   60048          2020       77.19   another_bug
# 2336           2015   92312          2016       54.68  engine_check
#
# [2337 rows x 10 columns]

# %%
df.target_class.value_counts()
# Out:
# target_class
# engine_overheat    289
# gear_stick         284
# another_bug        279
# engine_check       270
# break_bug          270
# engine_ignition    269
# engine_fuel        262
# electro_bug        249
# wheel_shake        165
# Name: count, dtype: int64

# %%
df2 = (df.target_class.groupby(df.car_type).value_counts())
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[42], line 1
# ----> 1 df2 = pd(df.target_class.groupby(df.car_type).value_counts())
#
# TypeError: 'module' object is not callable

# %%
df2.dtype
# Out:
# dtype('int64')
